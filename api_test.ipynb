# %%
from riotwatcher import TftWatcher, ApiError
import secret

RIOT_API_KEY = secret.RIOT_API_KEY
tft_watcher = TftWatcher(api_key='')
region = 'KR'
region_match = 'ASIA'

# %%
result = tft_watcher.league.rated_ladders(region, 'RANKED_TFT_TURBO')

# %%
result
# Out:
# [{'summonerId': 'wPkRtg9IJlrodFYcqPcnqjTDl-jA_UKPf5TVv3szbv6xAnQ',
#   'summonerName': '트위치빛나리',
#   'ratedTier': 'ORANGE',
#   'ratedRating': 5966,
#   'wins': 53,
#   'previousUpdateLadderPosition': 1},
#  {'summonerId': 'bSL0DlXqEVNucruAZXabb4dYX4dIX9T9xFyQCcLY_azXq-8GD00Wht17kA',
#   'summonerName': 'Kirche',
#   'ratedTier': 'ORANGE',
#   'ratedRating': 5734,
#   'wins': 39,
#   'previousUpdateLadderPosition': 2},
#  {'summonerId': 'UFPfQ4UOBerPTNjMA4vwxWQcfp61NAm0Zy9V9g2h6uCtEA',
#   'summonerName': '막 스',
#   'ratedTier': 'ORANGE',
#   'ratedRating': 5520,
#   'wins': 28,
#   'previousUpdateLadderPosition': 3},
#  {'summonerId': 'lCROIdA23bSiNE7QMBGeBynj5T9pruK-cIxOQyamg2XxV38',
#   'summonerName': '컬러병아리오백원',
#   'ratedTier': 'ORANGE',
#   'ratedRating': 5372,
#   'wins': 68,
#   'previousUpdateLadderPosition': 4},
#  {'summonerId': 'YWf8k4HWcH9TwS2LJ_w7Mrqbda0zPPROLJ1HUiqoOmDidQ',
#   'summonerName': '보고싶다 미안해',
#   'ratedTier': 'ORANGE',
#   'ratedRating': 5142,
# ...

# %%
tft_watcher.summoner.by_name(region, '트위치빛나리')
# Out:
# {'id': 'wPkRtg9IJlrodFYcqPcnqjTDl-jA_UKPf5TVv3szbv6xAnQ',
#  'accountId': 'X7syUqY9ss2Xo8mHNgkLpZJ0j1VJRzfdvJ8hTGLU8LzR-X8hA75eISu_',
#  'puuid': 'ekGRs-yHQj_Wx4umb91bxkAPrT61oJM0yp_rvrDV0JJ8keMqQJjDcJbcRDSw0xjqEhdD_a4UszNkBA',
#  'name': '트위치빛나리',
#  'profileIconId': 4273,
#  'revisionDate': 1620963867000,
#  'summonerLevel': 18}

# %%
tft_watcher.match.by_puuid(region_match, 'ekGRs-yHQj_Wx4umb91bxkAPrT61oJM0yp_rvrDV0JJ8keMqQJjDcJbcRDSw0xjqEhdD_a4UszNkBA', 20)
# Out:
# ['KR_5195117326',
#  'KR_5195042488',
#  'KR_5194807481',
#  'KR_5194842512',
#  'KR_5194558050',
#  'KR_5194625130',
#  'KR_5194612111',
#  'KR_5194529009',
#  'KR_5194476319',
#  'KR_5194015674',
#  'KR_5194002619',
#  'KR_5193756283',
#  'KR_5193478253',
#  'KR_5193462895',
#  'KR_5193363773',
#  'KR_5193318475',
#  'KR_5193283165',
#  'KR_5193188490',
#  'KR_5193203857',
#  'KR_5192984295']

# %%
tft_watcher.match.by_id(region_match, 'KR_5195117326')
# Out:
# {'metadata': {'data_version': '5',
#   'match_id': 'KR_5195117326',
#   'participants': ['x0tTr5261gfDLy6PbWuFj2yn661QFG1MkCeWIDXWt5o8SWYWs5y4M1KSB-8Stty5KEeu9Lu6qxrnaQ',
#    'gog_j2sSG6C6BY5mXgG87Tzh4m7XKqwCdMAvAD-FYQ0hU5RLWa50vH5-c1BElCFq9MItKuUBjX6FZg',
#    'YUPlem38M9TQRany5wbU1fxXxlJLvqvVYe_w5bLDalaPv9C7N2S1AmPEfsrdES5Bo8q4pwI2ScbyUw',
#    '_rfj68Hvg1t54c3x-qtOyUukpQRFwp_HtSko3jksG19RuQsPCONyNuJEAKPpKJd6UqG5Qf9pBbxG6w',
#    'A4WRPKW0fRQX4e9xSvVxuU5FY0kY2AXjCJTR6HZAtGkQaYWpB9VsMIgTikw5RnRaax1of2iHisIXgA',
#    'ekGRs-yHQj_Wx4umb91bxkAPrT61oJM0yp_rvrDV0JJ8keMqQJjDcJbcRDSw0xjqEhdD_a4UszNkBA',
#    '7Sjr2_-3v0TqknNjdxvPeMSlKbwT17z9GJDdfT7NKpmbuIduaufKL0_aHuSJ0Qb-syllHzXATVZcuw',
#    'JQtSgG2by3CSq5NivwMbWblQvLVgnVGm-v3RoD-DLLoIbv1PeTpSZlXoDiUa3yKwwhDcZBxG21yiTw']},
#  'info': {'game_datetime': 1620989066869,
#   'game_length': 2160.54052734375,
#   'game_version': 'Version 11.10.374.9538 (May 10 2021/13:12:58) [PUBLIC] <Releases/11.10>',
# ...

# %%
from lolchess.DatabaseManager import DatabaseManager
db = DatabaseManager()

# %%
from lolchess.model.participant import Participant

# %%
participants = db.session.query(Participant).all()
for participant in participants:
    print(participant.id)
# Out:
# 2021-05-14 21:26:28,041 INFO sqlalchemy.engine.Engine SELECT participants.id AS participants_id, participants.gold_left AS participants_gold_left, participants.last_round AS participants_last_round, participants.`level` AS participants_level, participants.placement AS participants_placement, participants.players_eliminated AS participants_players_eliminated, participants.time_eliminated AS participants_time_eliminated, participants.total_damage_to_players AS participants_total_damage_to_players, participants.champions AS participants_champions, participants.traits AS participants_traits, participants.match_id AS participants_match_id
# FROM participants
# 2021-05-14 21:26:28,041 INFO sqlalchemy.engine.Engine [generated in 0.00064s] {}
